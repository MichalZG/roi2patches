# %%
# %matplotlib inline
import numpy as np
import cv2
from read_roi import read_roi_zip
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
from matplotlib.collections import PatchCollection

# %%
rois_n = read_roi_zip('/home/pi/DATA/cells/zaznaczanie_fuji/patch12/11692a_x40_06_nuclei.tif.zip')
rois_b = read_roi_zip('/home/pi/DATA/cells/zaznaczanie_fuji/patch12/11692a_x40_06_background.tif.zip')
rois_c = read_roi_zip('/home/pi/DATA/cells/zaznaczanie_fuji/patch12/11692a_x40_06_cytoplasm.tif.zip')

# %%
im = cv2.imread('/home/pi/DATA/cells/zaznaczanie_fuji/patch12/11692a_x40_06.tif')

# %%
im
# Out:
# array([[[190, 171, 196],
#         [187, 167, 194],
#         [191, 174, 194],
#         ...,
#         [214, 216, 215],
#         [215, 216, 216],
#         [215, 217, 217]],
#
#        [[188, 171, 195],
#         [186, 168, 193],
#         [190, 173, 195],
#         ...,
#         [214, 215, 215],
#         [214, 215, 215],
#         [214, 216, 216]],
#
#        [[189, 173, 196],
#         [186, 171, 194],
#         [192, 174, 197],
#         ...,
#         [214, 215, 215],
#         [214, 215, 215],
#         [214, 216, 216]],
#
#        ...,
#        [[215, 217, 217],
#         [215, 217, 217],
#         [215, 217, 217],
#         ...,
#         [212, 211, 212],
#         [208, 205, 208],
#         [205, 199, 205]],
#
#        [[215, 217, 217],
#         [215, 217, 217],
#         [216, 217, 217],
#         ...,
#         [217, 216, 217],
#         [216, 214, 215],
#         [214, 211, 213]],
#
#        [[215, 217, 217],
#         [215, 217, 217],
#         [216, 218, 217],
# ...

# %%
fig = plt.figure(figsize=(30,30))
ax = fig.add_subplot(111)
ax.imshow(im)
xy_list = []
for rois in [rois_n]:
    for r in rois.values():
        xy = []
        for x, y in zip(r['x'], r['y']):
            xy.append([x, y])
        xy_list.append(np.array(xy))

# %%
#im_copy = im.copy()
for xy_i in xy_list:
    cv2.drawContours(im_copy, [xy_i], -1,(0,0,0),-1)

# %%
cv2.imshow(" ", im_copy)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('test.tif', im_copy)
# Out:
# True
